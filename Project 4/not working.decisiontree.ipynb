# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/itachi9604/disease-symptom-description-dataset

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
import pandas as pd
import dtreeviz

# %%
# load the diseases -dataset
df = pd.read_csv("diseases.csv")

# %%
df.describe()
# Out:
#                  Disease  Symptom_1  Symptom_2 Symptom_3    Symptom_4  \
# count               4920       4920       4920      4920         4572
# unique                41         34         48        54           50
# top     Fungal infection   vomiting   vomiting   fatigue   high_fever
# freq                 120        822        870       726          378
#
#         Symptom_5 Symptom_6        Symptom_7        Symptom_8  \
# count        3714      2934             2268             1944
# unique         38        32               26               21
# top      headache    nausea   abdominal_pain   abdominal_pain
# freq          348       390              264              276
#
#                  Symptom_9          Symptom_10     Symptom_11 Symptom_12  \
# count                 1692                1512           1194        744
# unique                  22                  21             18         11
# top      yellowing_of_eyes   yellowing_of_eyes   irritability    malaise
# ...

# %%
# check duplicates
df.duplicated().sum()
# Out:
# 4616

# %%
# remove duplicates
df.drop_duplicates(inplace=True)

# %%
# check nan values
df.isna().sum()
# Out:
# Disease         0
# Symptom_1       0
# Symptom_2       0
# Symptom_3       0
# Symptom_4      32
# Symptom_5      70
# Symptom_6     118
# Symptom_7     146
# Symptom_8     164
# Symptom_9     184
# Symptom_10    194
# Symptom_11    236
# Symptom_12    257
# Symptom_13    274
# Symptom_14    285
# Symptom_15    286
# Symptom_16    294
# Symptom_17    303
# dtype: int64

# %%
# remove nan values
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#             Disease             Symptom_1 Symptom_2 Symptom_3 Symptom_4  \
# count             1                     1         1         1         1
# unique            1                     1         1         1         1
# top     Common Cold   continuous_sneezing    chills   fatigue     cough
# freq              1                     1         1         1         1
#
#           Symptom_5  Symptom_6             Symptom_7 Symptom_8 Symptom_9  \
# count             1          1                     1         1         1
# unique            1          1                     1         1         1
# top      high_fever   headache   swelled_lymph_nodes   malaise    phlegm
# freq              1          1                     1         1         1
#
#                 Symptom_10        Symptom_11       Symptom_12   Symptom_13  \
# count                    1                 1                1            1
# unique                   1                 1                1            1
# ...

# %%
df.head()
# Out:
#          Disease             Symptom_1 Symptom_2 Symptom_3 Symptom_4  \
# 260  Common Cold   continuous_sneezing    chills   fatigue     cough
#
#        Symptom_5  Symptom_6             Symptom_7 Symptom_8 Symptom_9  \
# 260   high_fever   headache   swelled_lymph_nodes   malaise    phlegm
#
#              Symptom_10        Symptom_11       Symptom_12   Symptom_13  \
# 260   throat_irritation   redness_of_eyes   sinus_pressure   runny_nose
#
#       Symptom_14   Symptom_15      Symptom_16    Symptom_17
# 260   congestion   chest_pain   loss_of_smell   muscle_pain

# %%
# not all data is numeric
# use LabelEncoder to make it numeric
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
variables = ['Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4', 'Symptom_5', 'Symptom_6',
             'Symptom_7', 'Symptom_8', 'Symptom_9', 'Symptom_10', 'Symptom_11', 'Symptom_12',
             'Symptom_13', 'Symptom_14', 'Symptom_15', 'Symptom_16', 'Symptom_17']
encoder = LabelEncoder()
df[variables] = df[variables].apply(encoder.fit_transform)

# %%
df.head()
# Out:
#          Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 260  Common Cold          0          0          0          0          0
#
#      Symptom_6  Symptom_7  Symptom_8  Symptom_9  Symptom_10  Symptom_11  \
# 260          0          0          0          0           0           0
#
#      Symptom_12  Symptom_13  Symptom_14  Symptom_15  Symptom_16  Symptom_17
# 260           0           0           0           0           0           0

# %%
original_categories = encoder.classes_
print("Original categories:", original_categories)
# Out:
# Original categories: [' muscle_pain']

# %%
X = df.drop('Disease', axis=1)
y = df['Disease']

# %%
# Fit the decision tree classifier with default hyper-parameters
clf = DecisionTreeClassifier()
model = clf.fit(X, y)

# %%
# pip install dtreeviz
import dtreeviz
viz_model = dtreeviz.model(clf,
                           X_train=X, y_train=y,
                           feature_names=X.columns,
                           target_name='Decision',
                           class_names=["No", "Yes"])

# for viewing in the Jupyter notebook
# Note: this is not practical with large 
# decision trees!
# adjust the scale if you need a bigger picture (for example 2.5)
viz_model.view(scale=1.5).save("dt_titanic_test.svg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/dtreeviz/trees.py in view(self, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, leaftype, highlight_path, x, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale)
#     545             try:
# --> 546                 y_train = y_train.astype('float')
#     547             except ValueError as e:
#
# ValueError: could not convert string to float: 'Common Cold'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/8q/5qtfh2m96kd6nymxsdyfmr1w0000gn/T/ipykernel_56113/2580717180.py in <module>
#      11 # decision trees!
# ...
